# %% [markdown]
# To be able to do proper tests I need to be able to reproduce these bugs from code. This means I need add a noise removal step, undo adding the step and then add another noise removal step with the assistant from code:

# %%
import napari
from napari_assistant._gui._Assistant import Assistant
from skimage.io import imread
from napari_assistant._categories import CATEGORIES

filename = 'C:/Users/ryans/OneDrive/Desktop/blobs.tif'
blobs = imread(filename)

viewer = napari.Viewer()
viewer.add_image(blobs)
# Out:
# C:\Users\ryans\anaconda3\envs\np_workflows_v1\lib\site-packages\napari_tools_menu\__init__.py:165: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# <Image layer 'blobs' at 0x16bb8ffee90>

# %%
assistant = Assistant(viewer)
viewer.window.add_dock_widget(assistant)
assistant.load_workflow('simple workflow.yaml')
# Out:
#   loading args: (array([[ 40,  32,  24, ..., 216, 200, 200],
#        [ 56,  40,  24, ..., 232, 216, 216],
#        [ 64,  48,  24, ..., 240, 232, 232],
#        ...,
#        [ 72,  80,  80, ...,  48,  48,  48],
#        [ 80,  80,  80, ...,  48,  48,  48],
#        [ 96,  88,  80, ...,  48,  48,  48]], dtype=uint8),)
# loading kwargs: {'sigma': 4.0, 'viewer': Viewer(axes=Axes(visible=False, labels=True, colored=True, dashed=False, arrows=True), camera=Camera(center=(0.0, 126.5, 127.5), zoom=2.2403543307086613, angles=(0.0, 0.0, 90.0), perspective=0.0, interactive=True), cursor=Cursor(position=(1.0, 1.0), scaled=True, size=1, style=<CursorStyle.STANDARD: 'standard'>), dims=Dims(ndim=2, ndisplay=2, last_used=0, range=((0.0, 254.0, 1.0), (0.0, 256.0, 1.0)), current_step=(127, 128), order=(0, 1), axis_labels=('0', '1')), grid=GridCanvas(stride=-1, shape=(-1, -1), enabled=False), layers=[<Image layer 'blobs' at 0x16bb8ffee90>, <Image layer 'Result of Gaussian (scikit-image, nsbatwm)' at 0x16be8bf2260>], scale_bar=ScaleBar(visible=False, colored=False, ticks=True, position=<Position.BOTTOM_RIGHT: 'bottom_right'>, font_size=10.0, unit=None), text_overlay=TextOverlay(visible=False, color=array([0.5, 0.5, 0.5, 1. ]), font_size=10.0, position=<TextOverlayPosition.TOP_LEFT: 'top_left'>, text=''), overlays=Overlays(interaction_box=InteractionBox(points=None, show=False, show_handle=False, show_vertices=False, selection_box_drag=None, selection_box_final=None, transform_start=<napari.utils.transforms.transforms.Affine object at 0x0000016BD91B3D30>, transform_drag=<napari.utils.transforms.transforms.Affine object at 0x0000016BD91B3D90>, transform_final=<napari.utils.transforms.transforms.Affine object at 0x0000016BD91B3DF0>, transform=<napari.utils.transforms.transforms.Affine object at 0x0000016BD91B3E50>, allow_new_selection=True, selected_vertex=None)), help='', status='Ready', tooltip=Tooltip(visible=False, text=''), theme='dark', title='napari', mouse_move_callbacks=[<function InteractionBoxMouseBindings.initialize_mouse_events.<locals>.mouse_move at 0x0000016BE05BF9A0>], mouse_drag_callbacks=[<function InteractionBoxMouseBindings.initialize_mouse_events.<locals>.mouse_drag at 0x0000016BE05BD480>], mouse_double_click_callbacks=[], mouse_wheel_callbacks=[<function dims_scroll at 0x0000016BD7487370>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, keymap={'Shift': <function InteractionBoxMouseBindings.initialize_key_events.<locals>.hold_to_lock_aspect_ratio at 0x0000016BE05BE3B0>, 'Control-Shift-R': <function InteractionBoxMouseBindings._reset_active_layer_affine at 0x0000016BE06068C0>, 'Control-Shift-A': <function InteractionBoxMouseBindings._transform_active_layer at 0x0000016BE0607130>})}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\value_widget.py:57, in ValueWidget._on_value_change(self, value)
#      55 if value is self.null_value and not self._nullable:
#      56     return
# ---> 57 self.changed.emit(value)
#
# File ~\anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.py:670, in psygnal._signal.SignalInstance.emit()
#
# File ~\anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py:85, in SignalInstance._run_emit_loop(self, args)
#      83 # TODO: add better exception handling
#      84 if self._new_callback.get(slot):
# ---> 85     cb(*args[:max_args])
#      86 else:
#      87     cb(Event(args[0], self.name, self.instance))
#
# File ~\anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\container_widget.py:165, in ContainerWidget.insert.<locals>.<lambda>()
#     163 """Insert widget at ``key``."""
#     164 if isinstance(widget, (ValueWidget, ContainerWidget)):
# --> 165     widget.changed.connect(lambda: self.changed.emit(self))
#     166 _widget = widget
#     168 if self.labels:
#
# File ~\anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.py:670, in psygnal._signal.SignalInstance.emit()
#
# File ~\anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py:85, in SignalInstance._run_emit_loop(self, args)
#      83 # TODO: add better exception handling
#      84 if self._new_callback.get(slot):
# ---> 85     cb(*args[:max_args])
#      86 else:
#      87     cb(Event(args[0], self.name, self.instance))
#
# File ~\anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py:221, in FunctionGui._on_change(self)
#     219     self._dump()
#     220 if self._auto_call:
# --> 221     self()
#
# File ~\anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py:303, in FunctionGui.__call__(self, update_widget, *args, **kwargs)
#     301 self._tqdm_depth = 0  # reset the tqdm stack count
#     302 with _function_name_pointing_to_widget(self):
# --> 303     value = self._function(*bound.args, **bound.kwargs)
#     305 self._call_count += 1
#     306 if self._result_widget is not None:
#
# File c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow repositories\napari-assistant\napari_assistant\_workflow_io_utility.py:236, in make_flexible_gui.<locals>.worker_func(*iargs, **ikwargs)
#     234     print(f'  loading args: {iargs}')
#     235     print(f'loading kwargs: {ikwargs}')
# --> 236     workflow_manager.update(target_layer, func, *iargs, **ikwargs)
#     238     return None
#     239 else:
#
# File c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow repositories\napari-workflows\src\napari_workflows\_workflow.py:265, in WorkflowManager.update(self, target_layer, function, *args, **kwargs)
#     251 """
#     252 Update the task representing a given layer in the stored workflow by providing
#     253 the function and parameters that generated the data in the layer.
#    (...)
#     262 kwargs: dict
#     263 """
#     264 from ._workflowmanager_commands import Update_workflow_step
# --> 265 self.undo_redo_controller.execute(Update_workflow_step(
#     266     self.workflow,
#     267     self.viewer,
#     268     target_layer,
#     269     function,
#     270     *args,
#     271     **kwargs,
#     272     )
#     273 )
#     275 # set result valid
#     276 target_layer.metadata[METADATA_WORKFLOW_VALID_KEY] = True
#
# TypeError: Update_workflow_step.__init__() got multiple values for argument 'viewer'
#   loading args: (array([[ 40,  32,  24, ..., 216, 200, 200],
#        [ 56,  40,  24, ..., 232, 216, 216],
#        [ 64,  48,  24, ..., 240, 232, 232],
#        ...,
#        [ 72,  80,  80, ...,  48,  48,  48],
#        [ 80,  80,  80, ...,  48,  48,  48],
#        [ 96,  88,  80, ...,  48,  48,  48]], dtype=uint8),)
# loading kwargs: {'sigma': 4.0, 'viewer': Viewer(axes=Axes(visible=False, labels=True, colored=True, dashed=False, arrows=True), camera=Camera(center=(0.0, 126.5, 127.5), zoom=2.2403543307086613, angles=(0.0, 0.0, 90.0), perspective=0.0, interactive=True), cursor=Cursor(position=(1.0, 1.0), scaled=True, size=1, style=<CursorStyle.STANDARD: 'standard'>), dims=Dims(ndim=2, ndisplay=2, last_used=0, range=((0.0, 254.0, 1.0), (0.0, 256.0, 1.0)), current_step=(127, 128), order=(0, 1), axis_labels=('0', '1')), grid=GridCanvas(stride=-1, shape=(-1, -1), enabled=False), layers=[<Image layer 'blobs' at 0x16bb8ffee90>, <Image layer 'Result of Gaussian (scikit-image, nsbatwm)' at 0x16be8bf2260>], scale_bar=ScaleBar(visible=False, colored=False, ticks=True, position=<Position.BOTTOM_RIGHT: 'bottom_right'>, font_size=10.0, unit=None), text_overlay=TextOverlay(visible=False, color=array([0.5, 0.5, 0.5, 1. ]), font_size=10.0, position=<TextOverlayPosition.TOP_LEFT: 'top_left'>, text=''), overlays=Overlays(interaction_box=InteractionBox(points=None, show=False, show_handle=False, show_vertices=False, selection_box_drag=None, selection_box_final=None, transform_start=<napari.utils.transforms.transforms.Affine object at 0x0000016BD91B3D30>, transform_drag=<napari.utils.transforms.transforms.Affine object at 0x0000016BD91B3D90>, transform_final=<napari.utils.transforms.transforms.Affine object at 0x0000016BD91B3DF0>, transform=<napari.utils.transforms.transforms.Affine object at 0x0000016BD91B3E50>, allow_new_selection=True, selected_vertex=None)), help='', status='Ready', tooltip=Tooltip(visible=False, text=''), theme='dark', title='napari', mouse_move_callbacks=[<function InteractionBoxMouseBindings.initialize_mouse_events.<locals>.mouse_move at 0x0000016BE05BF9A0>], mouse_drag_callbacks=[<function InteractionBoxMouseBindings.initialize_mouse_events.<locals>.mouse_drag at 0x0000016BE05BD480>], mouse_double_click_callbacks=[], mouse_wheel_callbacks=[<function dims_scroll at 0x0000016BD7487370>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, keymap={'Shift': <function InteractionBoxMouseBindings.initialize_key_events.<locals>.hold_to_lock_aspect_ratio at 0x0000016BE05BE3B0>, 'Control-Shift-R': <function InteractionBoxMouseBindings._reset_active_layer_affine at 0x0000016BE06068C0>, 'Control-Shift-A': <function InteractionBoxMouseBindings._transform_active_layer at 0x0000016BE0607130>})}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 assistant = Assistant(viewer)
#       2 viewer.window.add_dock_widget(assistant)
# ----> 3 assistant.load_workflow('simple workflow.yaml')
#
# File c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow repositories\napari-assistant\napari_assistant\_gui\_Assistant.py:276, in Assistant.load_workflow(self, filename)
#     273     filename, _ = QFileDialog.getOpenFileName(self, "Import workflow ...", ".", "*.yaml")
#     274 self.workflow = _io_yaml_v1.load_workflow(filename)
# --> 276 initialise_root_functions(self.workflow,
#     277                           self._viewer)
#     278 load_remaining_workflow(workflow=self.workflow,
#     279                         viewer=self._viewer)
#
# File c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow repositories\napari-assistant\napari_assistant\_workflow_io_utility.py:79, in initialise_root_functions(workflow, viewer)
#      76     viewer.window.add_dock_widget(widget, name = wf_step_name[10:] + '<b> - SELECT INPUT</b>')
#      78 # calling the widget with the correct input images
# ---> 79 widget()
#
# File ~\anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py:303, in FunctionGui.__call__(self, update_widget, *args, **kwargs)
#     301 self._tqdm_depth = 0  # reset the tqdm stack count
#     302 with _function_name_pointing_to_widget(self):
# --> 303     value = self._function(*bound.args, **bound.kwargs)
#     305 self._call_count += 1
#     306 if self._result_widget is not None:
#
# File c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow repositories\napari-assistant\napari_assistant\_workflow_io_utility.py:236, in make_flexible_gui.<locals>.worker_func(*iargs, **ikwargs)
#     234     print(f'  loading args: {iargs}')
#     235     print(f'loading kwargs: {ikwargs}')
# --> 236     workflow_manager.update(target_layer, func, *iargs, **ikwargs)
#     238     return None
#     239 else:
#
# File c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow repositories\napari-workflows\src\napari_workflows\_workflow.py:265, in WorkflowManager.update(self, target_layer, function, *args, **kwargs)
#     251 """
#     252 Update the task representing a given layer in the stored workflow by providing
#     253 the function and parameters that generated the data in the layer.
#    (...)
#     262 kwargs: dict
#     263 """
#     264 from ._workflowmanager_commands import Update_workflow_step
# --> 265 self.undo_redo_controller.execute(Update_workflow_step(
#     266     self.workflow,
#     267     self.viewer,
#     268     target_layer,
#     269     function,
#     270     *args,
#     271     **kwargs,
#     272     )
#     273 )
#     275 # set result valid
#     276 target_layer.metadata[METADATA_WORKFLOW_VALID_KEY] = True
#
# TypeError: Update_workflow_step.__init__() got multiple values for argument 'viewer'

# %%
assistant.search_field.setText('nsb')
widget = assistant._activate(CATEGORIES.get("Remove noise"))
