# %% [markdown]
# To be able to do proper tests I need to be able to reproduce these bugs from code. This means I need add a noise removal step, undo adding the step and then add another noise removal step with the assistant from code:

# %%
import napari
from napari_assistant._gui._Assistant import Assistant
from skimage.io import imread
from napari_assistant._categories import CATEGORIES

filename = 'C:/Users/ryans/OneDrive/Desktop/blobs.tif'
blobs = imread(filename)

viewer = napari.Viewer()
viewer.add_image(blobs)
# Out:
# C:\Users\ryans\anaconda3\envs\np_workflows_v1\lib\site-packages\napari_tools_menu\__init__.py:165: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# <Image layer 'blobs' at 0x22189ed2530>

# %%
assistant = Assistant(viewer)
viewer.window.add_dock_widget(assistant)
assistant.load_workflow('simple workflow.yaml')
# Out:
# set workflow step: Result of Gaussian (scikit-image, nsbatwm)
#     args: ['blobs']
#   kwargs: {'sigma': 4.0}
# set workflow step: Result of Gaussian (scikit-image, nsbatwm)
#     args: []
#   kwargs: {}
# set workflow step: Result of Gaussian (scikit-image, nsbatwm)
#     args: ['blobs']
#   kwargs: {'sigma': 4.0}

# %%
assistant.search_field.setText('nsb')
widget = assistant._activate(CATEGORIES.get("Remove noise"))
# Out:
# set workflow step: Result of Gaussian (scikit-image, nsbatwm)
#     args: []
#   kwargs: {}
# set workflow step: Result of Gaussian (scikit-image, nsbatwm) [1]
#     args: ['Result of Gaussian (scikit-image, nsbatwm)', 1.0]
#   kwargs: {}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 assistant.search_field.setText('nsb')
# ----> 2 widget = assistant._activate(CATEGORIES.get("Remove noise"))
#
# File c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow repositories\napari-assistant\napari_assistant\_gui\_Assistant.py:197, in Assistant._activate(self, category)
#     194     pass # this happens if input0 should be labels but we provide an image
#     195 # call the function widget &
#     196 # track the association between the layer and the gui that generated it
# --> 197 self._layers[gui()] = (dw, gui)
#     198 # turn on auto_call, and make sure that if the input changes we update
#     199 gui._auto_call = True
#
# File ~\anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py:303, in FunctionGui.__call__(self, update_widget, *args, **kwargs)
#     301 self._tqdm_depth = 0  # reset the tqdm stack count
#     302 with _function_name_pointing_to_widget(self):
# --> 303     value = self._function(*bound.args, **bound.kwargs)
#     305 self._call_count += 1
#     306 if self._result_widget is not None:
#
# File c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow repositories\napari-assistant\napari_assistant\_gui\_category_widget.py:368, in make_gui_for_category.<locals>.gui_function(**kwargs)
#     366     from napari_workflows import WorkflowManager
#     367     manager = WorkflowManager.install(viewer)
# --> 368     manager.update(result_layer, find_function(op_name), *used_args)
#     369     #print("notified", result_layer.name, find_function(op_name))
#     370 except ImportError:
#
# File c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow repositories\napari-workflows\src\napari_workflows\_workflow.py:261, in WorkflowManager.update(self, target_layer, function, *args, **kwargs)
#     258 from ._workflowmanager_commands import Update_workflow_step
#     259 kwargs = {k:v for k,v in kwargs.items() if not ((isinstance(v, Viewer)) or (k == 'viewer'))}
# --> 261 self.undo_redo_controller.execute(Update_workflow_step(
#     262     self.workflow,
#     263     self.viewer,
#     264     target_layer,
#     265     function,
#     266     *args,
#     267     **kwargs,
#     268     )
#     269 )
#     271 # set result valid
#     272 target_layer.metadata[METADATA_WORKFLOW_VALID_KEY] = True
#
# File c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow repositories\napari-workflows\src\napari_workflows\_undo_redo_functionality.py:55, in Undo_redo_controller.execute(self, action)
#      51 if not self.freeze_stacks:
#      52     self.undo_stack.append(
#      53         copy_workflow_state(self.workflow)
#      54         )
# ---> 55 action.execute()
#
# File c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow repositories\napari-workflows\src\napari_workflows\_workflowmanager_commands.py:34, in Update_workflow_step.execute(self)
#      32     args = args[:-1]
#      33 args = tuple(args)
# ---> 34 self.workflow.set(self.target_layer.name, self.function, *args, **self.kwargs)
#      36 # plus the remove zombies function
#      37 kill_zombies(self.viewer,self.workflow)
#
# File c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow repositories\napari-workflows\src\napari_workflows\_workflow.py:55, in Workflow.set(self, name, func_or_data, *args, **kwargs)
#      53 # determine defaul parameters and apply them
#      54 sig = inspect.signature(func_or_data)
# ---> 55 bound = sig.bind(*args, **kwargs)
#      56 bound.apply_defaults()
#      58 # Go through arguments and in case it's a callable, remove it
#      59 # We should only have numbers, strings and images as parameters
#
# File ~\anaconda3\envs\np_workflows_v1\lib\inspect.py:3179, in Signature.bind(self, *args, **kwargs)
#    3174 def bind(self, /, *args, **kwargs):
#    3175     """Get a BoundArguments object, that maps the passed `args`
#    3176     and `kwargs` to the function's signature.  Raises `TypeError`
#    3177     if the passed arguments can not be bound.
#    3178     """
# -> 3179     return self._bind(args, kwargs)
#
# File ~\anaconda3\envs\np_workflows_v1\lib\inspect.py:3105, in Signature._bind(self, args, kwargs, partial)
#    3101 else:
#    3102     if param.kind in (_VAR_KEYWORD, _KEYWORD_ONLY):
#    3103         # Looks like we have no parameter for this positional
#    3104         # argument
# -> 3105         raise TypeError(
#    3106             'too many positional arguments') from None
#    3108     if param.kind == _VAR_POSITIONAL:
#    3109         # We have an '*args'-like argument, let's fill it with
#    3110         # all positional arguments we have left and move on to
#    3111         # the next phase
#    3112         values = [arg_val]
#
# TypeError: too many positional arguments
